# %%
import pandas as pd
# César Alejandro Neri Orozco - 8SM
# 1. Definir el path (URL Raw del archivo en GitHub)
# Nota: No se puede usar la URL normal que github da para el repositorio, se
# tiene que modificar para que apunte al contenido crudo del CSV.
path = "https://raw.githubusercontent.com/CesarNeri33/Neri_pipol_dataset/main/pipol_dataset.csv"
# Leer el archivo utilizando el comando para CSV.
df = pd.read_csv(path)
# 2. Mostrar la estructura o información del archivo
print("--- Información del DataFrame ---")
df.info()
# 3. Mostrar los primeros 5 elementos
print("\n--- Primeros 5 elementos ---")
print(df.head())
# 4. Mostrar las columnas con los datos: Nombre y País
print("\n--- Columnas: Name y Country ---")
print(df[['name', 'country']])
# 5. Mostrar por medio de índices (3 índices específicos) el contenido de las filas
print("\n--- Filas por índices (Ejemplo: 0, 10, 25) ---")
print(df.iloc[[0, 10, 25]])
# 6. Filtrar por país todos los que pertenecen a México
print("\n--- Personas en México ---")
mexico_df = df[df['country'] == 'Mexico']
print(mexico_df)
# 7. Filtrar por país México y que viven en Dusty City
print("\n--- Personas en Dusty City, México ---")
dusty_mexico_df = df[(df['country'] == 'Mexico') & (df['city'] == 'Dusty City')]
print(dusty_mexico_df)
# Out:
# --- Información del DataFrame ---
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       100 non-null    str
#  1   last_name  100 non-null    str
#  2   email      100 non-null    str
#  3   birthday   100 non-null    str
#  4   phone      100 non-null    str
#  5   city       100 non-null    str
#  6   country    100 non-null    str
# dtypes: str(7)
# memory usage: 5.6 KB
#
# --- Primeros 5 elementos ---
#       name last_name                      email    birthday        phone  \
# 0  Claudia   Chambas       Peinetas69@yahoo.com  04/04/1998  +52 2860679
# 1  Jessica   Barrett        michael04@yahoo.com  20/02/1992   +1 4088036
# 2    Wendy     Jones      vroberson@hotmail.com  22/12/1980  +34 6878987
# 3   Robert  Casillas        pwright@hotmail.com  30/11/1960  +52 3528441
# ...
